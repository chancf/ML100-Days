# %% [markdown]
# # 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# ### 資料來源：
# [ Black Friday: ]( https://www.kaggle.com/mehdidag/black-friday ) A study of sales trough consumer behaviours
#
# #### 你選的這組資料為何重要：
# 可以透過這間店的顧客資料與消費行為，規劃商品進貨量和促銷方式等行銷策略
# #### 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 一間零售店在黑色星期五的消費資料共550 000筆，資料庫來源為 Analytics Vidhya
# #### 蒐集而來的資料型態為何
# 結構化的數值包含年齡、居住時間、職業、購買數量、結帳金額等等。
# #### 這組資料想解決的問題如何評估
# 利用迴歸模式分析顧客的消費行為，找出與結帳金額高的相關因子。
# 也可以再透過分層資料分析消費者背景資料，找出促使不同族群結帳金額高的因子

# %% [markdown]
# # 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# #### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 如何提高載客率以提高營業額
#
# #### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 利用車用GPS和行車記錄器調查車隊司機的行車路線、行車時間、載客率、結帳金額，並且與公車、捷運路線交叉比對
# 利用問卷調查顧客滿意度與顧客年齡、叫車原因
#
# #### 3. 蒐集而來的資料型態為何
# 結構化數值與非結構化地圖圖表
#
# #### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 使用迴歸模式分析與高載客率的相關因子，並且與公車、捷運路線交叉比對找出高載客率的路段

# %% [markdown]
# # 作業3：
#
# 請點選檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式
#
# 資料夾結構建立規則提醒：ML100 > data資料夾 & ipynb檔
#
# (請注意data的存放位置，建議放在*.ipynb 同一個目錄下，這樣才能在不修改code的情況下正常執行)

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse
 
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 221.671
# The Mean absolute error is 11.823
